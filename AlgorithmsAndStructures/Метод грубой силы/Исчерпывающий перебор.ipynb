# %% [markdown]
# Многие важные задачи требуют поиска элемента со специальными свойствами. Подобные задачи чаще всего являются задачами *в оптимизационной постановке*: в них требуется найти элемент, который максимизирует или минимизирует некоторые интересующие нас характеристики. Например, длина пути или назначенная стоимость.
# **Исчерпывающий перебор (exhaustive search)** - подход к оптимизационным задачам с позиции грубой силы. Происходит генерация всех возможных элементов из области определения задачи, выбор тех, которые удовлетворяют накладываемым ограничениям, и далее поиск нужного элемента среди выбранных.

# %% [markdown]
# # Задача коммивояжера
# Найти такой кратчайший путь по заданным $n$ городам, чтобы каждый город посещался только один раз и конечным пунктом оказался город, с которого начиналось путешествие. Проблему можно смоделировалть с помощью взвешенного графа, **вершины** которого представляют собой города, а **веса ребер** определяют расстояния между городами.
#
# **Гамильтонов цикл (Hamiltonian circuit)** -  цикл, проходящий по всем вершинам графа ровно по одному разу. Таким образом, задача коммивожера сводится к задаче *поиска кратчайшего гамильтонова цикла*.
#
# Гамильтонов цикл можно определить как последовательность $n+1$ вершин $v_1, v_2, ..., v_n, v_1$. Таким образом, можно получить все возможные гамильтоновы циклы, сгенерировав перестановки $n-1$ вершин $v_2, ..., v_n$. Вычислив длину каждого гамильтонова цикла, можно выбрать наикратчайший.

# %%
# граф можно представить как два множества
# V - вершины, E - пары вершин, означающие ребра
V = {'a', 'b', 'c', 'd', 'e'}
E = {('a', 'b', 1), ('a', 'c', 2), ('a', 'd', 2), ('a', 'e', 2)
     ('b', 'c', 1), ('b', 'd', 2), ('b', 'e', 2),
     ('c', 'd', 1), ('c', 'e', 2),
     ('d', 'e', 1)}

# %% [markdown]
# # Задача о рюкзаке

# %% [markdown]
# # Задача о назначениях
