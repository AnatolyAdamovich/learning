# %% [markdown]
# # Решетчатый поиск
# Настройка параметров алгоритма является сложной задачей. Нужно понимать содержательный смысл этих параметров, прежде чем пытаться корректировать их. Библиотека scikit-learn предлагает стандартные методы для поиска оптимальных параметров. Одним из таких является *решетка*, которая перебирает все возможные комбинации параметров.

# %%
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

iris = load_iris()
X_train_and_val, X_test, y_train_and_val, y_test = train_test_split(iris.data, iris.target,
                                                   random_state=0)
print(f'Размер обучающего набора: {X_train_and_val.shape}')
print(f'Количество элементов в тестовом наборе: {len(y_test)}')
# Out:
# Размер обучающего набора: (112, 4)
# Количество элементов в тестовом наборе: 38

# %% [markdown]
# Теперь, однако, для оценки качества модели при разных вариациях параметров нужно использовать независимый набор данных:
# ![image.png](attachment:image.png)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_and_val,
                                                      y_train_and_val,
                                                     random_state=1)
print(f'Размер НАСТОЯЩЕГО обучающего набора: {X_train.shape}')
print(f'Количество элементов для валидации: {len(y_valid)}')
# Out:
# Размер НАСТОЯЩЕГО обучающего набора: (84, 4)
# Количество элементов для валидации: 28

# %% [markdown]
# **Важно**: необходимо всегда иметь независимый набор данных, используемый для конечной оценки (X_test, y_test в данном случае)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"C":[0.001, 0.01, 0.1, 1, 10, 100],
              "gamma": [0.01, 0.1, 1, 10, 100]}

# решетка с моделью SVC
# варьируемые параметры: C и gamma
# с исп. 5-блочной стратифицированной перекрестной проверки
grid = GridSearchCV(estimator=SVC(),
                   param_grid=param_grid,
                   cv=5)


# в данном случае будем использовать перекрестную проверку
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target,
                                                   random_state=0)
grid.fit(X_train, y_train)
grid
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'gamma': [0.01, 0.1, 1, 10, 100]})

# %% [markdown]
# Объект GridSearch автоматически перебирает все комбинации параметров, выбирает наилучшую (на основе проверок) и строит модель на этих наилучших параметрах

# %%
from sklearn.metrics import f1_score
print('F1 score = ', f1_score(grid.predict(X_test), y_test, average='micro'))
print('best parameters: ', grid.best_params_)
print('Средняя правильность во время обучения: ', grid.best_score_)
# Out:
# F1 score =  0.9736842105263158
# best parameters:  {'C': 10, 'gamma': 0.1}
# Средняя правильность во время обучения:  0.9731225296442687

# %% [markdown]
# Иногда очень важно визуализировать результаты проверок, чтобы понимать, как разные параметры влияют на обобщающую способность

# %%
import pandas as pd
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.004061      0.008122         0.001616        0.003231   0.001
# 1        0.001598      0.003196         0.000000        0.000000   0.001
# 2        0.000000      0.000000         0.000000        0.000000   0.001
# 3        0.001600      0.003201         0.000000        0.000000   0.001
# 4        0.000000      0.000000         0.000000        0.000000   0.001
# 5        0.001600      0.003201         0.000000        0.000000    0.01
# 6        0.000000      0.000000         0.001600        0.003199    0.01
# 7        0.000000      0.000000         0.000000        0.000000    0.01
# 8        0.001600      0.003200         0.000000        0.000000    0.01
# 9        0.001603      0.003205         0.000000        0.000000    0.01
# 10       0.000000      0.000000         0.000000        0.000000     0.1
# 11       0.001602      0.003204         0.000000        0.000000     0.1
# 12       0.000000      0.000000         0.000000        0.000000     0.1
# 13       0.000000      0.000000         0.000000        0.000000     0.1
# 14       0.000000      0.000000         0.000000        0.000000     0.1
# 15       0.000000      0.000000         0.001600        0.003200       1
# 16       0.000000      0.000000         0.000000        0.000000       1
# 17       0.001601      0.003202         0.000000        0.000000       1
# 18       0.001598      0.003197         0.000000        0.000000       1
# 19       0.001600      0.003201         0.000000        0.000000       1
# 20       0.000000      0.000000         0.000000        0.000000      10
# 21       0.000000      0.000000         0.001601        0.003201      10
# 22       0.000000      0.000000         0.000000        0.000000      10
# 23       0.000000      0.000000         0.001600        0.003199      10
# 24       0.001592      0.003183         0.000000        0.000000      10
# 25       0.000000      0.000000         0.000000        0.000000     100
# 26       0.001608      0.003217         0.000000        0.000000     100
# 27       0.001592      0.003183         0.000000        0.000000     100
# 28       0.000000      0.000000         0.000000        0.000000     100
# 29       0.000000      0.000000         0.001609        0.003217     100
#
#    param_gamma                       params  split0_test_score  \
# 0         0.01  {'C': 0.001, 'gamma': 0.01}           0.347826
# 1          0.1   {'C': 0.001, 'gamma': 0.1}           0.347826
# 2            1     {'C': 0.001, 'gamma': 1}           0.347826
# 3           10    {'C': 0.001, 'gamma': 10}           0.347826
# 4          100   {'C': 0.001, 'gamma': 100}           0.347826
# 5         0.01   {'C': 0.01, 'gamma': 0.01}           0.347826
# 6          0.1    {'C': 0.01, 'gamma': 0.1}           0.347826
# 7            1      {'C': 0.01, 'gamma': 1}           0.347826
# 8           10     {'C': 0.01, 'gamma': 10}           0.347826
# 9          100    {'C': 0.01, 'gamma': 100}           0.347826
# 10        0.01    {'C': 0.1, 'gamma': 0.01}           0.695652
# 11         0.1     {'C': 0.1, 'gamma': 0.1}           0.913043
# 12           1       {'C': 0.1, 'gamma': 1}           1.000000
# 13          10      {'C': 0.1, 'gamma': 10}           0.347826
# 14         100     {'C': 0.1, 'gamma': 100}           0.347826
# 15        0.01      {'C': 1, 'gamma': 0.01}           0.913043
# 16         0.1       {'C': 1, 'gamma': 0.1}           1.000000
# 17           1         {'C': 1, 'gamma': 1}           0.956522
# 18          10        {'C': 1, 'gamma': 10}           0.913043
# 19         100       {'C': 1, 'gamma': 100}           0.391304
# 20        0.01     {'C': 10, 'gamma': 0.01}           1.000000
# 21         0.1      {'C': 10, 'gamma': 0.1}           1.000000
# 22           1        {'C': 10, 'gamma': 1}           0.956522
# 23          10       {'C': 10, 'gamma': 10}           0.869565
# 24         100      {'C': 10, 'gamma': 100}           0.521739
# 25        0.01    {'C': 100, 'gamma': 0.01}           1.000000
# 26         0.1     {'C': 100, 'gamma': 0.1}           1.000000
# 27           1       {'C': 100, 'gamma': 1}           0.956522
# 28          10      {'C': 100, 'gamma': 10}           0.869565
# 29         100     {'C': 100, 'gamma': 100}           0.521739
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0